# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot( xpoints, ypoints, 'o-.m', ms =20, ls = ':',mec = 'b')
plt.savefig('plot.png')
# Out:
# C:\Users\ML\AppData\Local\Temp\ipykernel_17236\70011556.py:7: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-.m" (-> linestyle='-.'). The keyword argument will take precedence.
#   plt.plot( xpoints, ypoints, 'o-.m', ms =20, ls = ':',mec = 'b')

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('data.csv')
plt.imshow(data, cmap='hot', interpolation='nearest')


plt.colorbar()


plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Heatmap Example')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
df = pd.read_csv('data.csv')


# Create a scatter plot
df.plot(kind='scatter', x='Duration', y='Calories')

plt.show()


# # Save the plot to a file
# plt.savefig('plot.png')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data = pd.read_csv('data.csv')

corr_matrix = data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data = pd.read_csv('data.csv')

corr_matrix = data.corr()

plt.figure(figsize=(8, 6))
heatmap = plt.imshow(corr_matrix, interpolation='nearest', cmap='coolwarm')
plt.colorbar(heatmap)
plt.xticks(np.arange(len(corr_matrix.columns)), corr_matrix.columns, rotation=45)
plt.yticks(np.arange(len(corr_matrix.columns)), corr_matrix.columns)
plt.title('Correlation Matrix Heatmap')
for i in range(len(corr_matrix.columns)):
    for j in range(len(corr_matrix.columns)):
        text = plt.text(j, i, f'{corr_matrix.iloc[i, j]:.2f}',
                        ha='center', va='center', color='black')
plt.show()
